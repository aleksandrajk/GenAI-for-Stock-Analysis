# %% [markdown]
# # Setup

# %%
# List of assets to analyze
assets = [
    "Apple (AAPL)",
    "Amazon (AMZN)",
    "Bitcoin (BTC-USD)",
    "Alphabet (GOOGL)",
    "Meta (META)",
    "Microsoft (MSFT)",
    "Nvidia (NVDA)",
    "S&P 500 index (SPY)",
    "Tesla (TSLA)"
]

# Define the start and end years for the analysis
start_year = 2022
end_year = 2023
# Out:
# Can you provide a Python code snippet using the yfinance library to download historical stock data for the following assets for the years 2022 and 2023:
# Apple (AAPL), Amazon (AMZN), Bitcoin (BTC-USD), Alphabet (GOOGL), Meta (META), Microsoft (MSFT), Nvidia (NVDA), S&P 500 index (SPY), Tesla (TSLA)
